# %% [markdown]
# Installation requirement

# %%
# !pip install -U augly[audio]
# !sudo apt-get install python3-magic
# Out:
# Requirement already satisfied: augly[audio] in /usr/local/lib/python3.10/dist-packages (1.0.0)
# Requirement already satisfied: iopath>=0.1.8 in /usr/local/lib/python3.10/dist-packages (from augly[audio]) (0.1.10)
# Requirement already satisfied: python-magic>=0.4.22 in /usr/local/lib/python3.10/dist-packages (from augly[audio]) (0.4.27)
# Requirement already satisfied: regex>=2021.4.4 in /usr/local/lib/python3.10/dist-packages (from augly[audio]) (2023.12.25)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from augly[audio]) (3.0.1)
# Requirement already satisfied: librosa>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from augly[audio]) (0.10.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from augly[audio]) (1.25.2)
# Requirement already satisfied: SoundFile>=0.10.3.post1 in /usr/local/lib/python3.10/dist-packages (from augly[audio]) (0.12.1)
# Requirement already satisfied: torch>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from augly[audio]) (2.2.1+cu121)
# Requirement already satisfied: torchaudio>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from augly[audio]) (2.2.1+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from iopath>=0.1.8->augly[audio]) (4.66.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from iopath>=0.1.8->augly[audio]) (4.11.0)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from iopath>=0.1.8->augly[audio]) (2.8.2)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.8.1->augly[audio]) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.8.1->augly[audio]) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.8.1->augly[audio]) (1.4.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.8.1->augly[audio]) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.8.1->augly[audio]) (0.58.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.8.1->augly[audio]) (1.8.1)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.8.1->augly[audio]) (0.3.7)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.8.1->augly[audio]) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.8.1->augly[audio]) (1.0.8)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from SoundFile>=0.10.3.post1->augly[audio]) (1.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->augly[audio]) (3.13.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->augly[audio]) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->augly[audio]) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->augly[audio]) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->augly[audio]) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->augly[audio]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->augly[audio]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->augly[audio]) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->augly[audio]) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->augly[audio]) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->augly[audio]) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->augly[audio]) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->augly[audio]) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->augly[audio]) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->augly[audio]) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->augly[audio]) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->augly[audio]) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.9.0->augly[audio]) (12.4.127)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->SoundFile>=0.10.3.post1->augly[audio]) (2.22)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from lazy-loader>=0.1->librosa>=0.8.1->augly[audio]) (24.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa>=0.8.1->augly[audio]) (0.41.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa>=0.8.1->augly[audio]) (4.2.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa>=0.8.1->augly[audio]) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa>=0.8.1->augly[audio]) (3.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.9.0->augly[audio]) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.9.0->augly[audio]) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa>=0.8.1->augly[audio]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa>=0.8.1->augly[audio]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa>=0.8.1->augly[audio]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa>=0.8.1->augly[audio]) (2024.2.2)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3-magic is already the newest version (2:0.4.24-2).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %% [markdown]
# Import required libraries

# %%
import os
import augly.audio as audaugs
import augly.utils as utils
from IPython.display import display, Audio

# Get input audio
input_audio = "Trimmed-audio-258.m4a"
#os.path.join()
display(Audio(input_audio))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mp4;base64,..." type="audio/mp4" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Apply various augmentations to the audio

# %%
aug_audio, sr = audaugs.pitch_shift(input_audio, n_steps=4.0)
display(Audio(aug_audio, rate=sr))
# Out:
# /usr/local/lib/python3.10/dist-packages/augly/audio/utils.py:40: UserWarning: PySoundFile failed. Trying audioread instead.
#   return librosa.load(local_path, sr=None, mono=False)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Passing in a metadata list, to which metadata about the
# augmentation will be appended, including kwargs, the durations & number of
# channels of the input & output audio clips, the matching segments in the
# input/output audio clips (useful in case of temporal editing), and intensity
# (defined based on the kwargs for each augmentation)

# %%
meta = []
aug_audio, sr = audaugs.time_stretch(
    input_audio,
    rate=0.5,
    metadata=meta,
)
display(Audio(aug_audio, rate=sr))
meta
# Out:
# /usr/local/lib/python3.10/dist-packages/augly/audio/utils.py:40: UserWarning: PySoundFile failed. Trying audioread instead.
#   return librosa.load(local_path, sr=None, mono=False)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# [{'name': 'time_stretch',
#   'src_duration': 10.016,
#   'dst_duration': 20.032,
#   'src_num_channels': 1,
#   'dst_num_channels': 1,
#   'src_sample_rate': 32000,
#   'dst_sample_rate': 32000,
#   'src_segments': [{'start': 0.0, 'end': 10.016}],
#   'dst_segments': [{'start': 0.0, 'end': 20.032}],
#   'output_path': None,
#   'rate': 0.5,
#   'intensity': 20.0}]

# %%
# !apt-get install sox libsox-fmt-all
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libsox-fmt-all is already the newest version (14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1).
# sox is already the newest version (14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %% [markdown]
# For all the augmentations, we have class-based definitions as well as functional

# %% [markdown]
# Compose several transformations together

# %%
meta = []
aug = audaugs.Compose(
    [
        audaugs.AddBackgroundNoise(),
        audaugs.ToMono(),
        audaugs.Clicks(),
    ]
)
aug_audio, sr = aug(input_audio_arr, sample_rate=sr, metadata=meta)
display(Audio(aug_audio, rate=sr))
meta
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# [{'name': 'add_background_noise',
#   'src_duration': 10.016,
#   'dst_duration': 10.016,
#   'src_num_channels': 1,
#   'dst_num_channels': 1,
#   'src_sample_rate': 32000,
#   'dst_sample_rate': 32000,
#   'src_segments': [{'start': 0.0, 'end': 10.016}],
#   'dst_segments': [{'start': 0.0, 'end': 10.016}],
#   'background_audio': None,
#   'snr_level_db': 10.0,
#   'output_path': None,
#   'background_duration': 10.016,
#   'intensity': 90.9090909090909},
#  {'name': 'to_mono',
#   'src_duration': 10.016,
#   'dst_duration': 10.016,
#   'src_num_channels': 1,
#   'dst_num_channels': 1,
#   'src_sample_rate': 32000,
#   'dst_sample_rate': 32000,
#   'src_segments': [{'start': 0.0, 'end': 10.016}],
#   'dst_segments': [{'start': 0.0, 'end': 10.016}],
#   'output_path': None,
#   'intensity': 0.0},
#  {'name': 'clicks',
#   'src_duration': 10.016,
#   'dst_duration': 10.016,
#   'src_num_channels': 1,
#   'dst_num_channels': 1,
#   'src_sample_rate': 32000,
#   'dst_sample_rate': 32000,
#   'src_segments': [{'start': 0.0, 'end': 10.016}],
#   'dst_segments': [{'start': 0.0, 'end': 10.016}],
#   'seconds_between_clicks': 0.5,
#   'output_path': None,
#   'clicks_duration': 10.1,
#   'intensity': 98.26515151515153}]
